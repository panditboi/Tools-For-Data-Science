# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <p><b> Ashish Pandit </b></p>
# Data Scientist

# %% [markdown]
# <i> I'm intrested in data science because I love finding and recognizing patterns around me. I'm naturally curious and I want to use this inclination towards exploring meaning in data. </i>

# %% [markdown]
# <h3> Code to print the sum of two numbers </h3>

# %%
x = input("Type a number: ")
y = input("Type another number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)
# Out:
# Type a number: 5
# Type another number: 2
# The sum is:  7

# %% [markdown]
# <hr><strike> This is a strikethrough </strike><br>
# <hr>
# <a> This is a hyperlink </a>
